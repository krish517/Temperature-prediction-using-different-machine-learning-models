# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from keras import callbacks
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
np.random.seed(0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/RESEARCH/temp pred/Kalinchowk/Data/2003_2022_kalinchowk.csv")
data.head()
# Out:
#      YEAR   MO   DY    HR  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  TOA_SW_DWN  \
# 0  2003.0  1.0  1.0   6.0               0.00               0.00        0.00
# 1  2003.0  1.0  1.0   7.0               0.09               0.15        0.38
# 2  2003.0  1.0  1.0   8.0               0.30               0.85        1.34
# 3  2003.0  1.0  1.0   9.0               0.60               1.56        2.16
# 4  2003.0  1.0  1.0  10.0               0.92               2.12        2.77
#
#    ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  ...  T2MDEW  \
# 0                0.00                0.00            0.00  ...   -9.92
# 1                8.73               16.15            1.23  ...  -10.38
# 2               35.42               96.15            5.16  ...  -11.02
# 3               73.58              182.10           10.69  ...  -11.91
# 4              111.83              249.08           16.11  ...  -12.42
#
#    T2MWET  PRECTOTCORR    RH2M  QV2M     PS  WS2M     WS10M    WD2M   WD10M
# 0  -10.10          0.0  100.00  2.93  61.69  1.49  2.836444  218.19  218.23
# 1  -10.25          0.0  100.00  2.81  61.76  1.83  3.483687  226.04  226.43
# 2   -9.99          0.0   92.88  2.69  61.82  2.17  4.130929  234.37  234.22
# 3   -9.70          0.0   76.12  2.50  61.83  2.13  4.054783  237.13  237.06
# 4   -9.17          0.0   63.00  2.38  61.79  2.14  4.073819  239.22  238.92
#
# [5 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168714 entries, 0 to 168713
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 168690 non-null  float64
#  1   MO                   168690 non-null  float64
#  2   DY                   168690 non-null  float64
#  3   HR                   168690 non-null  float64
#  4   ALLSKY_SFC_SW_DWN    168690 non-null  float64
#  5   CLRSKY_SFC_SW_DWN    168690 non-null  float64
#  6   TOA_SW_DWN           168690 non-null  float64
#  7   ALLSKY_SFC_PAR_TOT   168690 non-null  float64
#  8   CLRSKY_SFC_PAR_TOT   168690 non-null  float64
#  9   ALLSKY_SFC_UVA       168690 non-null  float64
#  10  ALLSKY_SFC_UVB       168690 non-null  float64
#  11  ALLSKY_SFC_UV_INDEX  168690 non-null  float64
#  12  T2M                  168690 non-null  float64
#  13  T2MDEW               168690 non-null  float64
#  14  T2MWET               168690 non-null  float64
#  15  PRECTOTCORR          168690 non-null  float64
#  16  RH2M                 168690 non-null  float64
#  17  QV2M                 168690 non-null  float64
#  18  PS                   168690 non-null  float64
#  19  WS2M                 168690 non-null  float64
#  20  WS10M                168714 non-null  float64
#  21  WD2M                 168690 non-null  float64
#  22  WD10M                168690 non-null  float64
# dtypes: float64(23)
# memory usage: 29.6 MB

# %%
data.head()
# Out:
#      YEAR   MO   DY    HR  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  TOA_SW_DWN  \
# 0  2003.0  1.0  1.0   6.0               0.00               0.00        0.00
# 1  2003.0  1.0  1.0   7.0               0.09               0.15        0.38
# 2  2003.0  1.0  1.0   8.0               0.30               0.85        1.34
# 3  2003.0  1.0  1.0   9.0               0.60               1.56        2.16
# 4  2003.0  1.0  1.0  10.0               0.92               2.12        2.77
#
#    ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  ...  T2MDEW  \
# 0                0.00                0.00            0.00  ...   -9.92
# 1                8.73               16.15            1.23  ...  -10.38
# 2               35.42               96.15            5.16  ...  -11.02
# 3               73.58              182.10           10.69  ...  -11.91
# 4              111.83              249.08           16.11  ...  -12.42
#
#    T2MWET  PRECTOTCORR    RH2M  QV2M     PS  WS2M     WS10M    WD2M   WD10M
# 0  -10.10          0.0  100.00  2.93  61.69  1.49  2.836444  218.19  218.23
# 1  -10.25          0.0  100.00  2.81  61.76  1.83  3.483687  226.04  226.43
# 2   -9.99          0.0   92.88  2.69  61.82  2.17  4.130929  234.37  234.22
# 3   -9.70          0.0   76.12  2.50  61.83  2.13  4.054783  237.13  237.06
# 4   -9.17          0.0   63.00  2.38  61.79  2.14  4.073819  239.22  238.92
#
# [5 rows x 23 columns]

# %%
import pandas as pd

data["YEAR"] = data["YEAR"].astype(float)
data["MO"] = data["MO"].astype(float)
data["DY"] = data["DY"].astype(float)
data["HR"] = data["HR"].astype(float)

# %%
data.dropna(axis=0, inplace=True)

# %%
# data_2003_to_2021 = data[(data['YEAR'] >= 2003) & (data['YEAR'] <= 2021)]
# data_2022 = data[data['YEAR'] == 2022]

# %%
# data_2003_to_2021['YEAR'].unique()

# %%
Target=data['T2M']

# %%
Target
# Out:
# 0        -10.28
# 1        -10.12
# 2         -8.97
# 3         -7.49
# 4         -5.92
#           ...
# 168709     2.47
# 168710     2.18
# 168711     1.69
# 168712     1.07
# 168713     0.98
# Name: T2M, Length: 168690, dtype: float64

# %%
features = data.drop(['T2M', 'RH2M', 'T2MDEW', 'T2MWET'], axis=1)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168690 entries, 0 to 168713
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 168690 non-null  float64
#  1   MO                   168690 non-null  float64
#  2   DY                   168690 non-null  float64
#  3   HR                   168690 non-null  float64
#  4   ALLSKY_SFC_SW_DWN    168690 non-null  float64
#  5   CLRSKY_SFC_SW_DWN    168690 non-null  float64
#  6   TOA_SW_DWN           168690 non-null  float64
#  7   ALLSKY_SFC_PAR_TOT   168690 non-null  float64
#  8   CLRSKY_SFC_PAR_TOT   168690 non-null  float64
#  9   ALLSKY_SFC_UVA       168690 non-null  float64
#  10  ALLSKY_SFC_UVB       168690 non-null  float64
#  11  ALLSKY_SFC_UV_INDEX  168690 non-null  float64
#  12  PRECTOTCORR          168690 non-null  float64
#  13  QV2M                 168690 non-null  float64
#  14  PS                   168690 non-null  float64
#  15  WS2M                 168690 non-null  float64
#  16  WS10M                168690 non-null  float64
#  17  WD2M                 168690 non-null  float64
#  18  WD10M                168690 non-null  float64
# dtypes: float64(19)
# memory usage: 25.7 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(features, Target, test_size=0.2)

# %% [markdown]
# # xgb_model training

# %%
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
# Initialize the XGBoost Regressor
xgb_model = XGBRegressor()

# Fit the model to the training data
xgb_model.fit(X_train, y_train)

# Make predictions on the test data
xgb_predictions = xgb_model.predict(X_test)

# Evaluate the XGBoost model
xgb_mse = mean_squared_error(y_test, xgb_predictions)
xgb_mae = mean_absolute_error(y_test, xgb_predictions)
xgb_r2 = r2_score(y_test, xgb_predictions)

# Create a scatter plot of actual vs. predicted values
plt.scatter(y_test, xgb_predictions)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("XGBoost Regressor")
plt.show()

print("XGBoost Regressor:")
print(f"Mean Squared Error: {xgb_mse}")
print(f"Mean Absolute Error: {xgb_mae}")
print(f"R-squared (R2) Score: {xgb_r2}")
joblib.dump(xgb_model, '/content/drive/MyDrive/DataWind/your_model_name_xgb_kali_Temp.pkl')
# Out:
# XGBoost Regressor:
# Mean Squared Error: 1.3913894207247963
# Mean Absolute Error: 0.870620363446393
# R-squared (R2) Score: 0.9718756111845057
# ['/content/drive/MyDrive/DataWind/your_model_name_xgb_kali_Temp.pkl']

# %% [markdown]
# # xgb_model testing

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import joblib
model = joblib.load('/content/drive/MyDrive/DataWind/your_model_name_xgb_kali_Temp.pkl')
# Load your new data2022_mar-2023_may_solu.csv with your data file)
mar_may_data = pd.read_csv("/content/drive/MyDrive/RESEARCH/temp pred/Kalinchowk/Data/2022_apr-2023_may_kalinchowk.csv")
mar_may_data.dropna(axis=0, inplace=True)
# Extract the actual WS10M values from your new data
actual_T2M = mar_may_data['T2M']

# Drop unnecessary columns (if needed)
# For example, if 'WS2M' is not needed for prediction
mar_may_data = mar_may_data.drop(['T2M', 'RH2M', 'T2MDEW', 'T2MWET'], axis=1)

# Make predictions on the new data
predictions = model.predict(mar_may_data)

# Calculate the R-squared (R2) error
r2 = r2_score(actual_T2M, predictions)
xgb_mse = mean_squared_error(actual_T2M, predictions)
xgb_mae = mean_absolute_error(actual_T2M, predictions)
# Print R-squared error
print(f"R-squared (R2) error: {r2:.2f}")
print(f"Mean Squared Error: {xgb_mse:.2f}")
print(f"Mean Absolute Error: {xgb_mae:.2f}")

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(actual_T2M, label='Actual T2M', color='blue')
plt.plot(predictions, label='Predicted T2M', color='red')
plt.title('Actual vs. Predicted T2M for April 2022 - May 2023')
plt.xlabel('Data Point')
plt.ylabel('Temperature (T2M) deg celsius')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R-squared (R2) error: 0.90
# Mean Squared Error: 3.20
# Mean Absolute Error: 1.39

# %% [markdown]
# # RF_model training

# %%
# Initialize the RandomForestRegressor
model = RandomForestRegressor()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
predictions = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 1.114723643564527
# Mean Absolute Error: 0.7458708992827079

# %%
from sklearn.metrics import r2_score

# Calculate R-squared
r2 = r2_score(y_test, predictions)

print(f"R-squared: {r2}")
# Out:
# R-squared: 0.9774679031574769

# %% [markdown]
# # RF_model testing

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# Load your new data for Jul-Aug (replace with your data file)
mar_may_data = pd.read_csv("/content/drive/MyDrive/RESEARCH/temp pred/Kalinchowk/Data/2022_apr-2023_may_kalinchowk.csv")
mar_may_data.dropna(axis=0, inplace=True)
# Extract the actual WS10M values from your new data
actual_T2M = mar_may_data['T2M']

# Drop unnecessary columns (if needed)
# For example, if 'WS2M' is not needed for prediction
mar_may_data = mar_may_data.drop(['T2M', 'RH2M', 'T2MDEW', 'T2MWET'], axis=1)

# Make predictions on the new data
predictions = model.predict(mar_may_data)

# Calculate the R-squared (R2) error
r2 = r2_score(actual_T2M, predictions)
xgb_mse = mean_squared_error(actual_T2M, predictions)
xgb_mae = mean_absolute_error(actual_T2M, predictions)
# Print R-squared error
print(f"R-squared (R2) error: {r2:.2f}")
print(f"Mean Squared Error: {xgb_mse:.2f}")
print(f"Mean Absolute Error: {xgb_mae:.2f}")

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(actual_T2M, label='Actual T2M', color='blue')
plt.plot(predictions, label='Predicted T2M', color='red')
plt.title('Actual vs. Predicted T2M for April 2022 - May 2023')
plt.xlabel('Data Point')
plt.ylabel('Temperature (T2M) deg celsius')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R-squared (R2) error: 0.93
# Mean Squared Error: 2.22
# Mean Absolute Error: 1.06

# %% [markdown]
# # KNN_model training

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib

# Initialize the k-Nearest Neighbors Regressor
knn_model = KNeighborsRegressor()

# Fit the model to the training data
knn_model.fit(X_train, y_train)

# Make predictions on the test data
knn_predictions = knn_model.predict(X_test)

# Evaluate the KNN model
knn_mse = mean_squared_error(y_test, knn_predictions)
knn_mae = mean_absolute_error(y_test, knn_predictions)
knn_r2 = r2_score(y_test, knn_predictions)

# Create a scatter plot of actual vs. predicted values
plt.scatter(y_test, knn_predictions)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("k-Nearest Neighbors Regressor")
plt.show()

print("k-Nearest Neighbors Regressor:")
print(f"Mean Squared Error: {knn_mse}")
print(f"Mean Absolute Error: {knn_mae}")
print(f"R-squared (R2) Score: {knn_r2}")

# Save the KNN model to a file using joblib
joblib.dump(knn_model, '/content/drive/MyDrive/DataWind/your_model_name_knn_solu_Temp.pkl')
# Out:
# k-Nearest Neighbors Regressor:
# Mean Squared Error: 8.696652004623866
# Mean Absolute Error: 2.1101327286738987
# R-squared (R2) Score: 0.8242131076117568
# ['/content/drive/MyDrive/DataWind/your_model_name_knn_solu_Temp.pkl']

# %% [markdown]
# # KNN_model testing

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import joblib

# Load the saved KNN model
model = joblib.load('/content/drive/MyDrive/DataWind/your_model_name_knn_solu_Temp.pkl')


# Load your new data for Jul-Aug (replace with your data file)
mar_may_data = pd.read_csv("/content/drive/MyDrive/RESEARCH/temp pred/Kalinchowk/Data/2022_apr-2023_may_kalinchowk.csv")
mar_may_data.dropna(axis=0, inplace=True)
# Extract the actual WS10M values from your new data
actual_T2M = mar_may_data['T2M']

# Drop unnecessary columns (if needed)
# For example, if 'WS2M' is not needed for prediction
mar_may_data = mar_may_data.drop(['T2M', 'RH2M', 'T2MDEW', 'T2MWET'], axis=1)

# Make predictions on the new data
predictions = model.predict(mar_may_data)

# Calculate the R-squared (R2) error
r2 = r2_score(actual_T2M, predictions)
xgb_mse = mean_squared_error(actual_T2M, predictions)
xgb_mae = mean_absolute_error(actual_T2M, predictions)
# Print R-squared error
print(f"R-squared (R2) error: {r2:.2f}")
print(f"Mean Squared Error: {xgb_mse:.2f}")
print(f"Mean Absolute Error: {xgb_mae:.2f}")

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(actual_T2M, label='Actual T2M', color='blue')
plt.plot(predictions, label='Predicted T2M', color='red')
plt.title('Actual vs. Predicted T2M for April 2022 - May 2023')
plt.xlabel('Data Point')
plt.ylabel('Temperature (T2M) deg celsius')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R-squared (R2) error: 0.72
# Mean Squared Error: 9.46
# Mean Absolute Error: 2.26
